# %%
user1 = int(input("enter first number:"))
user2 = int(input("enter second number:"))
Multiply = user1 * user2
print("multiply")
# Out:
# multiply

# %%
# write a program that get two integer values from the User
# and multiply the output result
